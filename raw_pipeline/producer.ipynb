# %% [markdown]
# # Improved TikTok Producer Pipeline
#
# Pipeline này đã được cải tiến với:
# - Loại bỏ headless mode để tránh bị phát hiện bot
# - Thêm debug logging chi tiết
# - Error handling tốt hơn
# - Tăng thời gian chờ và retry logic

# %% [markdown]
# ## 1. Import Libraries & Setup

# %%
import re, time, random, pathlib
import logging
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.edge.options import Options as EdgeOptions

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def setup_driver(browser: str = "chrome"):
    """Setup WebDriver với cấu hình tối ưu để tránh bị phát hiện bot"""
    if browser.lower() == "chrome":
        opts = ChromeOptions()
    else:
        opts = EdgeOptions()
    
    # REMOVED --headless để tránh bị phát hiện bot
    opts.add_argument("--disable-blink-features=AutomationControlled")
    opts.add_experimental_option("excludeSwitches", ["enable-automation"])
    opts.add_experimental_option("useAutomationExtension", False)
    opts.add_argument("--no-sandbox")
    opts.add_argument("--disable-dev-shm-usage")
    opts.add_argument("--disable-web-security")
    opts.add_argument("--disable-features=VizDisplayCompositor")
    opts.add_argument("--disable-extensions")
    opts.add_argument("--disable-plugins")
    opts.add_argument("--disable-images")  # Tăng tốc độ load
    opts.add_argument(
        "--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36"
    )
    
    if browser.lower() == "chrome":
        driver = webdriver.Chrome(opts)
    else:
        driver = webdriver.Edge(opts)
    
    driver.execute_script("Object.defineProperty(navigator,'webdriver',{get:()=>undefined})")
    return driver

# Cập nhật regex patterns để khớp với nhiều format URL TikTok
URL_RE = re.compile(r"https://www\.tiktok\.com/@[\w\.-]+/video/(\d+)")
VIEW_RE = re.compile(r"([\d,\.]+)\s*[Vv]iews?")

def quick_views(a):
    """Extract view count từ element"""
    try:
        m = VIEW_RE.search(a.find_element(By.XPATH, ".//..").text)
        return int(m.group(1).replace(",", "").replace(".", "")) if m else None
    except: 
        return None

def crawl_ids_only(hashtag, num_videos=5, output_file='tiktok_ids.txt', min_views=0, browser="chrome"):
    """Crawl TikTok video IDs với debug và error handling tốt hơn"""
    driver = setup_driver(browser)
    url = f"https://www.tiktok.com/tag/{hashtag.lstrip('#')}"
    ids = set()
    
    logger.info(f"🔍 Bắt đầu crawl #{hashtag}")
    logger.info(f"   URL: {url}")
    logger.info(f"   Target: {num_videos} videos")
    logger.info(f"   Browser: {browser}")
    
    try:
        # Step 1: Load trang
        logger.info("   🌐 Đang mở trang...")
        driver.get(url)
        time.sleep(10)  # Tăng thời gian chờ
        
        # Step 2: Refresh để đảm bảo load đầy đủ
        logger.info("   🔄 Đang refresh trang...")
        driver.refresh()
        time.sleep(10)  # Tăng thời gian chờ
        
        # Step 3: Kiểm tra trang có load thành công không
        page_title = driver.title
        logger.info(f"   📄 Page title: {page_title}")
        
        # Step 4: Debug - Kiểm tra có bao nhiêu link trên trang
        all_links = driver.find_elements(By.TAG_NAME, "a")
        logger.info(f"   🔗 Tổng số links trên trang: {len(all_links)}")
        
        # Step 5: Debug - In ra một số link đầu tiên để kiểm tra
        tiktok_links = []
        for i, link in enumerate(all_links[:15]):
            href = link.get_attribute("href") or ""
            if "tiktok.com" in href:
                tiktok_links.append(href)
                logger.info(f"      Link {i+1}: {href}")
        
        logger.info(f"   🎯 Số TikTok links tìm thấy: {len(tiktok_links)}")
        
        # Step 6: Nếu không tìm thấy TikTok links, thử scroll
        if len(tiktok_links) == 0:
            logger.info("   ⚠️ Không tìm thấy TikTok links, thử scroll...")
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)
            driver.execute_script("window.scrollBy(0, 1000);")
            time.sleep(3)
            
            # Kiểm tra lại sau khi scroll
            all_links = driver.find_elements(By.TAG_NAME, "a")
            logger.info(f"   🔗 Sau scroll: {len(all_links)} links")

        # Step 7: Crawl video IDs
        scroll = 0
        while len(ids) < num_videos and scroll < 25:
            new = 0
            current_links = driver.find_elements(By.TAG_NAME, "a")
            logger.info(f"   📜 Scroll {scroll+1}: Tìm thấy {len(current_links)} links")
            
            for a in current_links:
                href = a.get_attribute("href") or ""
                m = URL_RE.match(href)
                vid = m.group(1) if m else None
                
                if not vid or vid in ids: 
                    continue
                    
                if min_views > 0:
                    v = quick_views(a)
                    if v is not None and v < min_views: 
                        continue
                        
                ids.add(vid)
                new += 1
                logger.info(f"      ✅ Tìm thấy video ID: {vid}")
                
                if len(ids) >= num_videos: 
                    break
                    
            logger.info(f"   📊 Đã crawl được {len(ids)} video IDs cho #{hashtag}")
            
            if new:
                time.sleep(3)
            else:
                logger.info("   📜 Không tìm thấy video mới, scroll xuống...")
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)  # Tăng thời gian chờ
                driver.execute_script("window.scrollBy(0,1000);")
                time.sleep(2)
                scroll += 1
                
    except Exception as e:
        logger.error(f"   ❌ Lỗi trong quá trình crawl: {e}")
        import traceback
        logger.error(f"   ❌ Traceback: {traceback.format_exc()}")
    finally:
        logger.info("   🔚 Đóng trình duyệt...")
        try:
            driver.quit()
        except:
            pass
        
    ids = list(ids)[:num_videos]
    if not ids:
        logger.warning(f"⚠️ Không crawl được video ID nào cho #{hashtag}")
        logger.info("💡 Gợi ý khắc phục:")
        logger.info("   1. Thử hashtag khác (viral, trending, dance)")
        logger.info("   2. Kiểm tra kết nối internet")
        logger.info("   3. Thử chạy vào thời điểm khác")
        logger.info("   4. TikTok có thể đã thay đổi cấu trúc trang")
        logger.info("   5. Thử browser khác (edge thay vì chrome)")
    else:
        logger.info(f"🎉 Thành công! Đã crawl được {len(ids)} video IDs")
        
    pathlib.Path(output_file).write_text("\n".join(ids), encoding="utf-8")
    return ids

# %% [markdown]
# ## 3. Improved Streaming Producer

# %%
import time
import subprocess
import os

def improved_streaming_producer(hashtags, interval=300, num_videos=5, topic_name='Test_with_MongoDB11'):
    """Improved streaming producer với error handling tốt hơn"""
    logger.info("🚀 Starting improved streaming producer...")
    
    while True:
        for hashtag in hashtags:
            logger.info(f'--- Streaming: Crawl & send for #{hashtag} ---')
            
            try:
                # Crawl IDs
                ids = crawl_ids_only(hashtag, num_videos, output_file='tiktok_ids.txt')
                logger.info(f"IDs: {ids}")
                
                if not ids:
                    logger.warning(f"⏩ Bỏ qua #{hashtag} vì không crawl được ID nào.")
                    continue
                    
                if not os.path.exists('tiktok_ids.txt') or os.path.getsize('tiktok_ids.txt') == 0:
                    logger.warning("⏩ File tiktok_ids.txt rỗng, bỏ qua.")
                    continue
                    
                # Send to Kafka
                try:
                    result = subprocess.run(
                        [
                            "python",
                            "run_kafka_producer_2.py",
                            "--ids_file", "tiktok_ids.txt",
                            "--topic", topic_name
                        ],
                        check=True,
                        capture_output=True,
                        text=True
                    )
                    logger.info("✅ Kafka producer completed successfully")
                    logger.info(result.stdout)
                except subprocess.CalledProcessError as e:
                    logger.error("❌ Error running run_kafka_producer_2.py")
                    logger.error(f"STDOUT: {e.stdout}")
                    logger.error(f"STDERR: {e.stderr}")
                      
            except Exception as e:
                logger.error(f"❌ Error processing hashtag #{hashtag}: {e}")
                continue
                
        logger.info(f'⏳ Sleeping {interval}s before next round...')
        time.sleep(interval)

# Uncomment để chạy streaming producer
hashtags = ['funny', 'viral', 'trending', 'dance', 'comedy']
improved_streaming_producer(hashtags, interval=300, num_videos=5, topic_name='Test_with_MongoDB11')
# Out:
# 2025-07-16 23:29:46,837 - INFO - 🚀 Starting improved streaming producer...
# 2025-07-16 23:29:46,840 - INFO - --- Streaming: Crawl & send for #funny ---
# 2025-07-16 23:29:48,536 - INFO - 🔍 Bắt đầu crawl #funny
# 2025-07-16 23:29:48,539 - INFO -    URL: https://www.tiktok.com/tag/funny
# 2025-07-16 23:29:48,540 - INFO -    Target: 5 videos
# 2025-07-16 23:29:48,541 - INFO -    Browser: chrome
# 2025-07-16 23:29:48,543 - INFO -    🌐 Đang mở trang...
# 2025-07-16 23:30:00,799 - INFO -    🔄 Đang refresh trang...
# 2025-07-16 23:30:11,108 - INFO -    📄 Page title: TikTok - Make Your Day
# 2025-07-16 23:30:11,176 - INFO -    🔗 Tổng số links trên trang: 410
# 2025-07-16 23:30:11,195 - INFO -       Link 1: https://www.tiktok.com/
# 2025-07-16 23:30:11,206 - INFO -       Link 2: https://www.tiktok.com/
# 2025-07-16 23:30:11,219 - INFO -       Link 3: https://www.tiktok.com/
# 2025-07-16 23:30:11,231 - INFO -       Link 4: https://www.tiktok.com/explore
# 2025-07-16 23:30:11,241 - INFO -       Link 5: https://www.tiktok.com/following
# 2025-07-16 23:30:11,253 - INFO -       Link 6: https://www.tiktok.com/tiktokstudio/upload?from=webapp
# 2025-07-16 23:30:11,263 - INFO -       Link 7: https://www.tiktok.com/live
# 2025-07-16 23:30:11,274 - INFO -       Link 8: https://www.tiktok.com/@
# 2025-07-16 23:30:11,286 - INFO -       Link 9: https://www.tiktok.com/@danielduro069/video/7519121499287031070
# 2025-07-16 23:30:11,298 - INFO -       Link 10: https://www.tiktok.com/@danielduro069?lang=en
# 2025-07-16 23:30:11,309 - INFO -       Link 11: https://www.tiktok.com/@danielduro069?lang=en
# 2025-07-16 23:30:11,320 - INFO -       Link 12: https://www.tiktok.com/@danielduro069/video/7519121499287031070
# 2025-07-16 23:30:11,331 - INFO -       Link 13: https://www.tiktok.com/tag/fyp
# 2025-07-16 23:30:11,342 - INFO -       Link 14: https://www.tiktok.com/tag/ranking
# 2025-07-16 23:30:11,352 - INFO -       Link 15: https://www.tiktok.com/tag/top5
# 2025-07-16 23:30:11,353 - INFO -    🎯 Số TikTok links tìm thấy: 15
# 2025-07-16 23:30:11,410 - INFO -    📜 Scroll 1: Tìm thấy 410 links
# 2025-07-16 23:30:11,489 - INFO -       ✅ Tìm thấy video ID: 7519121499287031070
# 2025-07-16 23:30:11,581 - INFO -       ✅ Tìm thấy video ID: 7520099847152635166
# 2025-07-16 23:30:11,725 - INFO -       ✅ Tìm thấy video ID: 7524247246729121055
# 2025-07-16 23:30:11,843 - INFO -       ✅ Tìm thấy video ID: 7527280429045517575
# 2025-07-16 23:30:11,967 - INFO -       ✅ Tìm thấy video ID: 7514698176192990486
# 2025-07-16 23:30:11,968 - INFO -    📊 Đã crawl được 5 video IDs cho #funny
# 2025-07-16 23:30:14,971 - INFO -    🔚 Đóng trình duyệt...
# 2025-07-16 23:30:17,393 - INFO - 🎉 Thành công! Đã crawl được 5 video IDs
# 2025-07-16 23:30:17,399 - INFO - IDs: ['7527280429045517575', '7514698176192990486', '7520099847152635166', '7524247246729121055', '7519121499287031070']
# 2025-07-16 23:30:23,459 - INFO - ✅ Kafka producer completed successfully
# 2025-07-16 23:30:23,461 - INFO - 2025-07-16 23:30:20,181 - __main__ - INFO - [run_kafka_producer_2.py:159] - 🔍 Starting run_kafka_producer.py...
# 2025-07-16 23:30:20,182 - __main__ - INFO - [run_kafka_producer_2.py:160] - 📋 Command line arguments: ['run_kafka_producer_2.py', '--ids_file', 'tiktok_ids.txt', '--topic', 'Test_with_MongoDB11']
# 2025-07-16 23:30:20,191 - __main__ - INFO - [run_kafka_producer_2.py:73] - ======================================================================
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:74] - 🚀 RUN_KAFKA_PRODUCER STARTING
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:75] - ======================================================================
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:76] - ⏰ Start time: 2025-07-16 23:30:20.192418
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:88] - ⚙️ Configuration:
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:89] -    Kafka Broker: localhost:9092
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:90] -    Topic: Test_with_MongoDB11
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:92] -    IDs file: tiktok_ids.txt
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:95] -    Videos: 3
# 2025-07-16 23:30:20,192 - __main__ - INFO - [run_kafka_producer_2.py:98] - 🔌 Creating Kafka producer...
# 2025-07-16 23:30:20,192 - kafka_producer - INFO - [kafka_producer.py:256] - 🔌 Creating Kafka producer for: localhost:9092
# 2025-07-16 23:30:20,192 - kafka_producer - INFO - [kafka_producer.py:236] - 🔌 Testing Kafka connection to: localhost:9092
# 2025-07-16 23:30:20,198 - kafka_producer - INFO - [kafka_producer.py:246] - ✅ Kafka connection test successful: localhost:9092
# 2025-07-16 23:30:20,199 - kafka_producer - DEBUG - [kafka_producer.py:261] - ⚙️ Configuring Kafka producer...
# 2025-07-16 23:30:20,199 - kafka.producer.kafka - DEBUG - [kafka.py:468] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Starting Kafka producer
# 2025-07-16 23:30:20,201 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name connections-closed
# 2025-07-16 23:30:20,201 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name connections-created
# 2025-07-16 23:30:20,201 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name select-time
# 2025-07-16 23:30:20,201 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name io-time
# 2025-07-16 23:30:20,201 - kafka.client - DEBUG - [client_async.py:1052] - Attempting to check version with node bootstrap-0
# 2025-07-16 23:30:20,201 - kafka.client - DEBUG - [client_async.py:446] - Initiating connection to node bootstrap-0 at localhost:9092
# 2025-07-16 23:30:20,202 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name bytes-sent-received
# 2025-07-16 23:30:20,202 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name bytes-sent
# 2025-07-16 23:30:20,202 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name bytes-received
# 2025-07-16 23:30:20,203 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name request-latency
# 2025-07-16 23:30:20,203 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name throttle-time
# 2025-07-16 23:30:20,203 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-bootstrap-0.bytes-sent
# 2025-07-16 23:30:20,203 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-bootstrap-0.bytes-received
# 2025-07-16 23:30:20,203 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-bootstrap-0.latency
# 2025-07-16 23:30:20,204 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-bootstrap-0.throttle
# 2025-07-16 23:30:20,204 - kafka.conn - DEBUG - [conn.py:377] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [unspecified None]>: creating new socket
# 2025-07-16 23:30:20,206 - kafka.conn - DEBUG - [conn.py:391] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: setting socket option (6, 1, 1)
# 2025-07-16 23:30:20,206 - kafka.conn - INFO - [conn.py:396] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-07-16 23:30:20,206 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 200.000000, metadata inf, idle connection inf, request inf
# 2025-07-16 23:30:20,207 - kafka.conn - DEBUG - [conn.py:413] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: established TCP connection
# 2025-07-16 23:30:20,207 - kafka.conn - DEBUG - [conn.py:423] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_send> [IPv6 ('::1', 9092, 0, 0)]>: checking broker Api Versions
# 2025-07-16 23:30:20,207 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ApiVersionsRequest_v4(client_software_name='kafka-python', client_software_version='2.2.15', _tagged_fields={})
# 2025-07-16 23:30:20,207 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_send> [IPv6 ('::1', 9092, 0, 0)]>: Request 1 (timeout_ms 1000.0): ApiVersionsRequest_v4(client_software_name='kafka-python', client_software_version='2.2.15', _tagged_fields={})
# 2025-07-16 23:30:20,207 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 200.000000, metadata inf, idle connection inf, request 1000.000000
# 2025-07-16 23:30:20,211 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 1
# 2025-07-16 23:30:20,211 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ApiVersionsResponse_v4
# 2025-07-16 23:30:20,212 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Response 1 (4.988670349121094 ms): ApiVersionsResponse_v0(error_code=35, api_versions=[(api_key=18, min_version=0, max_version=3)])
# 2025-07-16 23:30:20,212 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 200.000000, metadata inf, idle connection 539988.000000, request inf
# 2025-07-16 23:30:20,212 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ApiVersionsRequest_v3(client_software_name='kafka-python', client_software_version='2.2.15', _tagged_fields={})
# 2025-07-16 23:30:20,212 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_send> [IPv6 ('::1', 9092, 0, 0)]>: Request 2 (timeout_ms 500.0): ApiVersionsRequest_v3(client_software_name='kafka-python', client_software_version='2.2.15', _tagged_fields={})
# 2025-07-16 23:30:20,213 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 200.000000, metadata inf, idle connection 539986.000000, request 498.577356
# 2025-07-16 23:30:20,214 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 2
# 2025-07-16 23:30:20,214 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ApiVersionsResponse_v3
# 2025-07-16 23:30:20,216 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Response 2 (3.951549530029297 ms): ApiVersionsResponse_v3(error_code=0, api_versions=[(api_key=0, min_version=0, max_version=9, _tagged_fields={}), (api_key=1, min_version=0, max_version=15, _tagged_fields={}), (api_key=2, min_version=0, max_version=8, _tagged_fields={}), (api_key=3, min_version=0, max_version=12, _tagged_fields={}), (api_key=4, min_version=0, max_version=7, _tagged_fields={}), (api_key=5, min_version=0, max_version=4, _tagged_fields={}), (api_key=6, min_version=0, max_version=8, _tagged_fields={}), (api_key=7, min_version=0, max_version=3, _tagged_fields={}), (api_key=8, min_version=0, max_version=8, _tagged_fields={}), (api_key=9, min_version=0, max_version=8, _tagged_fields={}), (api_key=10, min_version=0, max_version=4, _tagged_fields={}), (api_key=11, min_version=0, max_version=9, _tagged_fields={}), (api_key=12, min_version=0, max_version=4, _tagged_fields={}), (api_key=13, min_version=0, max_version=5, _tagged_fields={}), (api_key=14, min_version=0, max_version=5, _tagged_fields={}), (api_key=15, min_version=0, max_version=5, _tagged_fields={}), (api_key=16, min_version=0, max_version=4, _tagged_fields={}), (api_key=17, min_version=0, max_version=1, _tagged_fields={}), (api_key=18, min_version=0, max_version=3, _tagged_fields={}), (api_key=19, min_version=0, max_version=7, _tagged_fields={}), (api_key=20, min_version=0, max_version=6, _tagged_fields={}), (api_key=21, min_version=0, max_version=2, _tagged_fields={}), (api_key=22, min_version=0, max_version=4, _tagged_fields={}), (api_key=23, min_version=0, max_version=4, _tagged_fields={}), (api_key=24, min_version=0, max_version=4, _tagged_fields={}), (api_key=25, min_version=0, max_version=3, _tagged_fields={}), (api_key=26, min_version=0, max_version=3, _tagged_fields={}), (api_key=27, min_version=0, max_version=1, _tagged_fields={}), (api_key=28, min_version=0, max_version=3, _tagged_fields={}), (api_key=29, min_version=0, max_version=3, _tagged_fields={}), (api_key=30, min_version=0, max_version=3, _tagged_fields={}), (api_key=31, min_version=0, max_version=3, _tagged_fields={}), (api_key=32, min_version=0, max_version=4, _tagged_fields={}), (api_key=33, min_version=0, max_version=2, _tagged_fields={}), (api_key=34, min_version=0, max_version=2, _tagged_fields={}), (api_key=35, min_version=0, max_version=4, _tagged_fields={}), (api_key=36, min_version=0, max_version=2, _tagged_fields={}), (api_key=37, min_version=0, max_version=3, _tagged_fields={}), (api_key=38, min_version=0, max_version=3, _tagged_fields={}), (api_key=39, min_version=0, max_version=2, _tagged_fields={}), (api_key=40, min_version=0, max_version=2, _tagged_fields={}), (api_key=41, min_version=0, max_version=3, _tagged_fields={}), (api_key=42, min_version=0, max_version=2, _tagged_fields={}), (api_key=43, min_version=0, max_version=2, _tagged_fields={}), (api_key=44, min_version=0, max_version=1, _tagged_fields={}), (api_key=45, min_version=0, max_version=0, _tagged_fields={}), (api_key=46, min_version=0, max_version=0, _tagged_fields={}), (api_key=47, min_version=0, max_version=0, _tagged_fields={}), (api_key=48, min_version=0, max_version=1, _tagged_fields={}), (api_key=49, min_version=0, max_version=1, _tagged_fields={}), (api_key=50, min_version=0, max_version=0, _tagged_fields={}), (api_key=51, min_version=0, max_version=0, _tagged_fields={}), (api_key=56, min_version=0, max_version=3, _tagged_fields={}), (api_key=57, min_version=0, max_version=1, _tagged_fields={}), (api_key=58, min_version=0, max_version=0, _tagged_fields={}), (api_key=60, min_version=0, max_version=0, _tagged_fields={}), (api_key=61, min_version=0, max_version=0, _tagged_fields={}), (api_key=65, min_version=0, max_version=0, _tagged_fields={}), (api_key=66, min_version=0, max_version=0, _tagged_fi ...
# 2025-07-16 23:30:20,218 - kafka.conn - INFO - [conn.py:618] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# 2025-07-16 23:30:20,218 - kafka.conn - INFO - [conn.py:457] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-07-16 23:30:20,219 - kafka.client - DEBUG - [client_async.py:338] - Node bootstrap-0 connected
# 2025-07-16 23:30:20,219 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name batch-size
# 2025-07-16 23:30:20,219 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name compression-rate
# 2025-07-16 23:30:20,219 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name queue-time
# 2025-07-16 23:30:20,219 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name records-per-request
# 2025-07-16 23:30:20,220 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name bytes
# 2025-07-16 23:30:20,220 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name record-retries
# 2025-07-16 23:30:20,220 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name errors
# 2025-07-16 23:30:20,220 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name record-size-max
# 2025-07-16 23:30:20,221 - kafka.producer.sender - DEBUG - [sender.py:105] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Starting Kafka producer I/O thread.
# 2025-07-16 23:30:20,221 - kafka.producer.kafka - DEBUG - [kafka.py:564] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Kafka producer started
# 2025-07-16 23:30:20,221 - kafka.client - DEBUG - [client_async.py:990] - Sending metadata request MetadataRequest_v7(topics=[], allow_auto_topic_creation=True) to node bootstrap-0
# 2025-07-16 23:30:20,222 - kafka_producer - INFO - [kafka_producer.py:277] - ✅ Kafka producer created successfully
# 2025-07-16 23:30:20,222 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request MetadataRequest_v7(topics=[], allow_auto_topic_creation=True)
# 2025-07-16 23:30:20,222 - __main__ - INFO - [run_kafka_producer_2.py:109] - ✅ Producer created in 0.03s
# 2025-07-16 23:30:20,223 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Request 3 (timeout_ms 30000): MetadataRequest_v7(topics=[], allow_auto_topic_creation=True)
# 2025-07-16 23:30:20,223 - __main__ - INFO - [run_kafka_producer_2.py:112] - 📤 Starting sending process...
# 2025-07-16 23:30:20,223 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999987.000000, metadata 30000.000000, idle connection 539977.000000, request 30000.000000
# 2025-07-16 23:30:20,223 - __main__ - INFO - [run_kafka_producer_2.py:116] - 📤 Sending metadata from ids file: tiktok_ids.txt
# 2025-07-16 23:30:20,224 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 30000.000000, idle connection 539976.000000, request 29998.985291
# 2025-07-16 23:30:20,228 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 3
# 2025-07-16 23:30:20,228 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response MetadataResponse_v7
# 2025-07-16 23:30:20,229 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Response 3 (5.515098571777344 ms): MetadataResponse_v7(throttle_time_ms=0, brokers=[(node_id=0, host='host.docker.internal', port=9092, rack=None)], cluster_id='4gX7yxdoToSmh8dilGmeLw', controller_id=0, topics=[])
# 2025-07-16 23:30:20,229 - kafka.cluster - DEBUG - [cluster.py:354] - Updated cluster metadata to ClusterMetadata(brokers: 1, topics: 0, coordinators: 0)
# 2025-07-16 23:30:20,229 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 300000.000000, idle connection 539971.000000, request inf
# 2025-07-16 23:30:20,819 - urllib3.connectionpool - DEBUG - [connectionpool.py:1049] - Starting new HTTPS connection (1): www.tiktok.com:443
# 2025-07-16 23:30:21,267 - urllib3.connectionpool - DEBUG - [connectionpool.py:544] - https://www.tiktok.com:443 "GET /@tiktok/video/7527280429045517575 HTTP/1.1" 200 None
# 2025-07-16 23:30:21,324 - urllib3.connectionpool - DEBUG - [connectionpool.py:1049] - Starting new HTTPS connection (1): www.tiktok.com:443
# 2025-07-16 23:30:21,638 - urllib3.connectionpool - DEBUG - [connectionpool.py:544] - https://www.tiktok.com:443 "GET /@tiktok/video/7514698176192990486 HTTP/1.1" 200 None
# 2025-07-16 23:30:21,689 - urllib3.connectionpool - DEBUG - [connectionpool.py:1049] - Starting new HTTPS connection (1): www.tiktok.com:443
# 2025-07-16 23:30:22,047 - urllib3.connectionpool - DEBUG - [connectionpool.py:544] - https://www.tiktok.com:443 "GET /@tiktok/video/7520099847152635166 HTTP/1.1" 200 None
# 2025-07-16 23:30:22,114 - urllib3.connectionpool - DEBUG - [connectionpool.py:1049] - Starting new HTTPS connection (1): www.tiktok.com:443
# 2025-07-16 23:30:22,533 - urllib3.connectionpool - DEBUG - [connectionpool.py:544] - https://www.tiktok.com:443 "GET /@tiktok/video/7524247246729121055 HTTP/1.1" 200 70961
# 2025-07-16 23:30:22,581 - urllib3.connectionpool - DEBUG - [connectionpool.py:1049] - Starting new HTTPS connection (1): www.tiktok.com:443
# 2025-07-16 23:30:22,967 - urllib3.connectionpool - DEBUG - [connectionpool.py:544] - https://www.tiktok.com:443 "GET /@tiktok/video/7519121499287031070 HTTP/1.1" 200 None
# 2025-07-16 23:30:23,052 - kafka.producer.kafka - DEBUG - [kafka.py:957] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Requesting metadata update for topic Test_with_MongoDB11
# 2025-07-16 23:30:23,053 - kafka.client - DEBUG - [client_async.py:964] - Initializing connection to node 0 for metadata request
# 2025-07-16 23:30:23,053 - kafka.client - DEBUG - [client_async.py:446] - Initiating connection to node 0 at host.docker.internal:9092
# 2025-07-16 23:30:23,053 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-0.bytes-sent
# 2025-07-16 23:30:23,054 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-0.bytes-received
# 2025-07-16 23:30:23,054 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-0.latency
# 2025-07-16 23:30:23,054 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name node-0.throttle
# 2025-07-16 23:30:23,056 - kafka.conn - DEBUG - [conn.py:377] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connecting> [unspecified None]>: creating new socket
# 2025-07-16 23:30:23,056 - kafka.conn - DEBUG - [conn.py:391] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connecting> [IPv4 ('192.168.1.97', 9092)]>: setting socket option (6, 1, 1)
# 2025-07-16 23:30:23,057 - kafka.conn - INFO - [conn.py:396] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connecting> [IPv4 ('192.168.1.97', 9092)]>: connecting to host.docker.internal:9092 [('192.168.1.97', 9092) IPv4]
# 2025-07-16 23:30:23,058 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999984.000000, metadata inf, idle connection 537141.000000, request inf
# 2025-07-16 23:30:23,058 - kafka.conn - DEBUG - [conn.py:413] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connecting> [IPv4 ('192.168.1.97', 9092)]>: established TCP connection
# 2025-07-16 23:30:23,058 - kafka.conn - DEBUG - [conn.py:423] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <checking_api_versions_send> [IPv4 ('192.168.1.97', 9092)]>: checking broker Api Versions
# 2025-07-16 23:30:23,059 - kafka.conn - DEBUG - [conn.py:549] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <checking_api_versions_send> [IPv4 ('192.168.1.97', 9092)]>: Using pre-configured api_version (2, 6) for ApiVersions
# 2025-07-16 23:30:23,059 - kafka.conn - INFO - [conn.py:457] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Connection complete.
# 2025-07-16 23:30:23,059 - kafka.client - DEBUG - [client_async.py:338] - Node 0 connected
# 2025-07-16 23:30:23,059 - kafka.conn - INFO - [conn.py:945] - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-07-16 23:30:23,060 - kafka.client - DEBUG - [client_async.py:990] - Sending metadata request MetadataRequest_v7(topics=['Test_with_MongoDB11'], allow_auto_topic_creation=True) to node 0
# 2025-07-16 23:30:23,060 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request MetadataRequest_v7(topics=['Test_with_MongoDB11'], allow_auto_topic_creation=True)
# 2025-07-16 23:30:23,061 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Request 1 (timeout_ms 30000): MetadataRequest_v7(topics=['Test_with_MongoDB11'], allow_auto_topic_creation=True)
# 2025-07-16 23:30:23,061 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999988.000000, metadata 30000.000000, idle connection 537138.000000, request 30000.000000
# 2025-07-16 23:30:23,062 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 30000.000000, idle connection 537137.000000, request 29999.004126
# 2025-07-16 23:30:23,070 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 1
# 2025-07-16 23:30:23,071 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response MetadataResponse_v7
# 2025-07-16 23:30:23,071 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 1 (9.659528732299805 ms): MetadataResponse_v7(throttle_time_ms=0, brokers=[(node_id=0, host='host.docker.internal', port=9092, rack=None)], cluster_id='4gX7yxdoToSmh8dilGmeLw', controller_id=0, topics=[(error_code=0, topic='Test_with_MongoDB11', is_internal=False, partitions=[(error_code=0, partition=0, leader=0, leader_epoch=0, replicas=[0], isr=[0], offline_replicas=[])])])
# 2025-07-16 23:30:23,072 - kafka.cluster - DEBUG - [cluster.py:354] - Updated cluster metadata to ClusterMetadata(brokers: 1, topics: 1, coordinators: 0)
# 2025-07-16 23:30:23,072 - kafka.producer.kafka - DEBUG - [kafka.py:971] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: _wait_on_metadata woke after 0.02 secs.
# 2025-07-16 23:30:23,073 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299998.999756, idle connection 537127.000000, request inf
# 2025-07-16 23:30:23,073 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7514698176192990486', 'url': 'https://www.tiktok.com/@quymeuvjf53/video/7514698176192990486', 'username': 'quymeuvjf53', 'author_name': 'Scarecam Prank 😂', 'description': 'Try not to laugh 😂😂😂 #funny #animals #funnypets #funnyanimals #catsoftiktok #funnytiktok #cat #haha #dog #pet #funnyvideos ', 'hashtags': ['funny', 'animals', 'funnypets', 'funnyanimals', 'catsoftiktok', 'funnytiktok', 'cat', 'haha', 'dog', 'pet', 'funnyvideos'], 'playcount': 42900000, 'diggcount': 1100000, 'commentcount': 7022, 'sharecount': 139600, 'music_title': 'original sound', 'music_author': 'Scarecam Prank 😂', 'duration': 62, 'width': 576, 'height': 1024, 'created_time': '2025-06-11T21:27:00'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,074 - kafka.producer.kafka - DEBUG - [kafka.py:876] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Waking up the sender since TopicPartition(topic='Test_with_MongoDB11', partition=0) is either full or getting a new batch
# 2025-07-16 23:30:23,074 - kafka_producer - INFO - [kafka_producer.py:484] - ✅ Đã gửi metadata cho video 7514698176192990486
# 2025-07-16 23:30:23,075 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 8.000000, metadata 299996.687256, idle connection 537124.000000, request inf
# 2025-07-16 23:30:23,088 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name topic.Test_with_MongoDB11.records-per-batch
# 2025-07-16 23:30:23,088 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name topic.Test_with_MongoDB11.bytes
# 2025-07-16 23:30:23,088 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name topic.Test_with_MongoDB11.compression-rate
# 2025-07-16 23:30:23,089 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name topic.Test_with_MongoDB11.record-retries
# 2025-07-16 23:30:23,089 - kafka.metrics.metrics - DEBUG - [metrics.py:157] - Added sensor with name topic.Test_with_MongoDB11.record-errors
# 2025-07-16 23:30:23,089 - kafka.producer.sender - DEBUG - [sender.py:257] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Nodes with data ready to send: {0}
# 2025-07-16 23:30:23,089 - kafka.producer.sender - DEBUG - [sender.py:258] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Created 1 produce requests: {0: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x01\x00\x00\x00\x00\x02\x1dsc\x81\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x12\xa5b\x00\x00\x01\x98\x14\x12\xa5b\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\x9c\x0b\x00\x00\x00\x08null\x86\x0b{"video_id": "7514698176192...')])])}
# 2025-07-16 23:30:23,090 - kafka.producer.sender - DEBUG - [sender.py:269] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Sending Produce Request: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x01\x00\x00\x00\x00\x02\x1dsc\x81\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x12\xa5b\x00\x00\x01\x98\x14\x12\xa5b\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\x9c\x0b\x00\x00\x00\x08null\x86\x0b{"video_id": "7514698176192...')])])
# 2025-07-16 23:30:23,090 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x01\x00\x00\x00\x00\x02\x1dsc\x81\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x12\xa5b\x00\x00\x01\x98\x14\x12\xa5b\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\x9c\x0b\x00\x00\x00\x08null\x86\x0b{"video_id": "7514698176192...')])])
# 2025-07-16 23:30:23,091 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Request 2 (timeout_ms 30000): ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x01\x00\x00\x00\x00\x02\x1dsc\x81\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x12\xa5b\x00\x00\x01\x98\x14\x12\xa5b\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\x9c\x0b\x00\x00\x00\x08null\x86\x0b{"video_id": "7514698176192...')])])
# 2025-07-16 23:30:23,091 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 0.000000, metadata 299981.511963, idle connection 537109.000000, request 30000.000000
# 2025-07-16 23:30:23,091 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119983.000000, metadata 299981.511963, idle connection 537109.000000, request 30000.000000
# 2025-07-16 23:30:23,097 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7519121499287031070', 'url': 'https://www.tiktok.com/@danielduro069/video/7519121499287031070', 'username': 'danielduro069', 'author_name': 'Daniel Duro', 'description': 'Babies are too funny😭#fyp #ranking #top5 #babiesoftiktok #baby #funny #viral ', 'hashtags': ['fyp', 'ranking', 'top5', 'babiesoftiktok', 'baby', 'funny', 'viral'], 'playcount': 5300000, 'diggcount': 939500, 'commentcount': 1809, 'sharecount': 141800, 'music_title': 'original sound', 'music_author': 'Daniel Duro', 'duration': 61, 'width': 576, 'height': 1024, 'created_time': '2025-06-23T19:32:17'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,099 - kafka.producer.kafka - DEBUG - [kafka.py:876] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Waking up the sender since TopicPartition(topic='Test_with_MongoDB11', partition=0) is either full or getting a new batch
# 2025-07-16 23:30:23,099 - kafka_producer - INFO - [kafka_producer.py:484] - ✅ Đã gửi metadata cho video 7519121499287031070
# 2025-07-16 23:30:23,100 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119974.000000, metadata 299972.267822, idle connection 537100.000000, request 29990.755796
# 2025-07-16 23:30:23,120 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7520099847152635166', 'url': 'https://www.tiktok.com/@funnypetsoftiktok49/video/7520099847152635166', 'username': 'funnypetsoftiktok49', 'author_name': 'funnypetsoftiktok49', 'description': "“Cat： I'm the star!”#fyp\xa0#foryou\xa0#cat\xa0#petlove #catsoftiktok\xa0#catlover\xa0#funny\xa0#funnyvideos\xa0#fypage\xa0#funnycat\xa0#funnytiktok\xa0#cats", 'hashtags': ['fyp', 'foryou', 'cat', 'petlove', 'catsoftiktok', 'catlover', 'funny', 'funnyvideos', 'fypage', 'funnycat', 'funnytiktok', 'cats'], 'playcount': 6100000, 'diggcount': 1500000, 'commentcount': 2480, 'sharecount': 159500, 'music_title': 'Funny', 'music_author': 'Gold-Tiger', 'duration': 64, 'width': 576, 'height': 1024, 'created_time': '2025-06-26T10:48:24'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,122 - kafka_producer - INFO - [kafka_producer.py:484] - ✅ Đã gửi metadata cho video 7520099847152635166
# 2025-07-16 23:30:23,147 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7524247246729121055', 'url': 'https://www.tiktok.com/@funnypanda.media/video/7524247246729121055', 'username': 'funnypanda.media', 'author_name': 'Gấu mập hề hước', 'description': '#funnyvideos #funny #funnyanimals #comedyvideo #comdy #lucu #fy #fypシ #foryou #xuhuong ', 'hashtags': ['funnyvideos', 'funny', 'funnyanimals', 'comedyvideo', 'comdy', 'lucu', 'fy', 'fypシ', 'foryou', 'xuhuong'], 'playcount': 3400000, 'diggcount': 178100, 'commentcount': 3296, 'sharecount': 30400, 'music_title': 'son original', 'music_author': 'hakimducongo01🇨🇩', 'duration': 66, 'width': 576, 'height': 1024, 'created_time': '2025-07-07T15:02:48'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,148 - kafka_producer - INFO - [kafka_producer.py:484] - ✅ Đã gửi metadata cho video 7524247246729121055
# 2025-07-16 23:30:23,177 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7527280429045517575', 'url': 'https://www.tiktok.com/@shafu009/video/7527280429045517575', 'username': 'shafu009', 'author_name': 'Funny', 'description': '#粉丝一千万#pet#pets#cute#funny#viral#funnyvideos#foryou#IoI#fyp#fypシ゚ ', 'hashtags': ['粉丝一千万', 'pet', 'pets', 'cute', 'funny', 'viral', 'funnyvideos', 'foryou', 'ioi', 'fyp', 'fypシ゚'], 'playcount': 3900000, 'diggcount': 99600, 'commentcount': 8323, 'sharecount': 53700, 'music_title': 'оригинальный звук', 'music_author': 'baxtliy_yigit_n1', 'duration': 7, 'width': 576, 'height': 1026, 'created_time': '2025-07-15T19:12:31'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,178 - kafka_producer - INFO - [kafka_producer.py:484] - ✅ Đã gửi metadata cho video 7527280429045517575
# 2025-07-16 23:30:23,178 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:30:23,180 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:583] - Waiting on produce to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,181 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119893.000000, metadata 299890.821045, idle connection 537019.000000, request 29909.308910
# 2025-07-16 23:30:23,187 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 2
# 2025-07-16 23:30:23,187 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ProduceResponse_v7
# 2025-07-16 23:30:23,187 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 2 (96.19688987731934 ms): ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=0, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:30:23,188 - kafka.producer.sender - DEBUG - [sender.py:399] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Parsing produce response: ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=0, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:30:23,188 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:131] - Successfully produced messages to TopicPartition(topic='Test_with_MongoDB11', partition=0) with base offset 0
# 2025-07-16 23:30:23,193 - kafka.producer.sender - DEBUG - [sender.py:257] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Nodes with data ready to send: {0}
# 2025-07-16 23:30:23,193 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:583] - Waiting on produce to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:30:23,194 - kafka.producer.sender - DEBUG - [sender.py:258] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Created 1 produce requests: {0: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x94\x00\x00\x00\x00\x02i:YJ\x00\x00\x00\x00\x00\x03\x00\x00\x01\x98\x14\x12\xa5{\x00\x00\x01\x98\x14\x12\xa5\xc9\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x04\xac\t\x00\x00\x00\x08null\x96\t{"video_id": "7519121499287...')])])}
# 2025-07-16 23:30:23,195 - kafka.producer.sender - DEBUG - [sender.py:269] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Sending Produce Request: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x94\x00\x00\x00\x00\x02i:YJ\x00\x00\x00\x00\x00\x03\x00\x00\x01\x98\x14\x12\xa5{\x00\x00\x01\x98\x14\x12\xa5\xc9\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x04\xac\t\x00\x00\x00\x08null\x96\t{"video_id": "7519121499287...')])])
# 2025-07-16 23:30:23,195 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x94\x00\x00\x00\x00\x02i:YJ\x00\x00\x00\x00\x00\x03\x00\x00\x01\x98\x14\x12\xa5{\x00\x00\x01\x98\x14\x12\xa5\xc9\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x04\xac\t\x00\x00\x00\x08null\x96\t{"video_id": "7519121499287...')])])
# 2025-07-16 23:30:23,195 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Request 3 (timeout_ms 30000): ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x94\x00\x00\x00\x00\x02i:YJ\x00\x00\x00\x00\x00\x03\x00\x00\x01\x98\x14\x12\xa5{\x00\x00\x01\x98\x14\x12\xa5\xc9\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x04\xac\t\x00\x00\x00\x08null\x96\t{"video_id": "7519121499287...')])])
# 2025-07-16 23:30:23,196 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 0.000000, metadata 299877.369141, idle connection 537005.000000, request 30000.000000
# 2025-07-16 23:30:23,196 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119902.000000, metadata 299875.858643, idle connection 537004.000000, request 29998.489380
# 2025-07-16 23:30:23,202 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 3
# 2025-07-16 23:30:23,202 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ProduceResponse_v7
# 2025-07-16 23:30:23,203 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 3 (8.553266525268555 ms): ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=1, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:30:23,203 - kafka.producer.sender - DEBUG - [sender.py:399] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Parsing produce response: ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=1, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:30:23,204 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:131] - Successfully produced messages to TopicPartition(topic='Test_with_MongoDB11', partition=0) with base offset 1
# 2025-07-16 23:30:23,204 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299867.814697, idle connection 536996.000000, request inf
# 2025-07-16 23:30:23,205 - kafka_producer - INFO - [kafka_producer.py:489] - 🎉 Đã gửi xong metadata cho 5 video IDs trong tiktok_ids.txt!
# 2025-07-16 23:30:23,205 - __main__ - INFO - [run_kafka_producer_2.py:128] - ✅ Sending completed in 2.98s
# 2025-07-16 23:30:23,205 - __main__ - INFO - [run_kafka_producer_2.py:131] - 🧹 Cleaning up producer...
# 2025-07-16 23:30:23,206 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:30:23,207 - kafka.producer.kafka - INFO - [kafka.py:629] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Closing the Kafka producer with 4294967.0 secs timeout.
# 2025-07-16 23:30:23,208 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299863.791748, idle connection 536991.000000, request inf
# 2025-07-16 23:30:23,209 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:30:23,210 - kafka.producer.sender - DEBUG - [sender.py:114] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Beginning shutdown of Kafka producer I/O thread, sending remaining records.
# 2025-07-16 23:30:23,212 - kafka.conn - INFO - [conn.py:945] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Closing connection.
# 2025-07-16 23:30:23,213 - kafka.producer.sender - DEBUG - [sender.py:138] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Shutdown of Kafka producer I/O thread has completed.
# 2025-07-16 23:30:23,213 - kafka.producer.kafka - DEBUG - [kafka.py:662] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: The Kafka producer has closed.
# 2025-07-16 23:30:23,214 - __main__ - INFO - [run_kafka_producer_2.py:138] - ✅ Cleanup completed in 0.01s
# 2025-07-16 23:30:23,214 - __main__ - INFO - [run_kafka_producer_2.py:141] - 🎉 SUCCESS - All operations completed successfully!
# 2025-07-16 23:30:23,214 - __main__ - INFO - [run_kafka_producer_2.py:179] - ⏱️ Total execution time: 3.02s
# 2025-07-16 23:30:23,215 - __main__ - INFO - [run_kafka_producer_2.py:182] - 🎉 Program completed successfully!
#
# 2025-07-16 23:30:23,463 - INFO - --- Streaming: Crawl & send for #viral ---
# 2025-07-16 23:30:26,737 - INFO - 🔍 Bắt đầu crawl #viral
# 2025-07-16 23:30:26,740 - INFO -    URL: https://www.tiktok.com/tag/viral
# 2025-07-16 23:30:26,743 - INFO -    Target: 5 videos
# 2025-07-16 23:30:26,744 - INFO -    Browser: chrome
# 2025-07-16 23:30:26,746 - INFO -    🌐 Đang mở trang...
# 2025-07-16 23:30:39,963 - INFO -    🔄 Đang refresh trang...
# 2025-07-16 23:30:50,275 - INFO -    📄 Page title: #viral | TikTok
# 2025-07-16 23:30:50,402 - INFO -    🔗 Tổng số links trên trang: 438
# 2025-07-16 23:30:50,449 - INFO -       Link 1: https://www.tiktok.com/
# 2025-07-16 23:30:50,463 - INFO -       Link 2: https://www.tiktok.com/
# 2025-07-16 23:30:50,477 - INFO -       Link 3: https://www.tiktok.com/
# 2025-07-16 23:30:50,489 - INFO -       Link 4: https://www.tiktok.com/explore
# 2025-07-16 23:30:50,502 - INFO -       Link 5: https://www.tiktok.com/following
# 2025-07-16 23:30:50,514 - INFO -       Link 6: https://www.tiktok.com/tiktokstudio/upload?from=webapp
# 2025-07-16 23:30:50,527 - INFO -       Link 7: https://www.tiktok.com/live
# 2025-07-16 23:30:50,540 - INFO -       Link 8: https://www.tiktok.com/@
# 2025-07-16 23:30:50,562 - INFO -       Link 10: https://www.tiktok.com/@yllpr/video/7496578131843714309
# 2025-07-16 23:30:50,581 - INFO -       Link 11: https://www.tiktok.com/@yllpr?lang=en
# 2025-07-16 23:30:50,595 - INFO -       Link 12: https://www.tiktok.com/@yllpr?lang=en
# 2025-07-16 23:30:50,607 - INFO -       Link 13: https://www.tiktok.com/@yllpr/video/7496578131843714309
# 2025-07-16 23:30:50,626 - INFO -       Link 14: https://www.tiktok.com/tag/dog
# 2025-07-16 23:30:50,643 - INFO -       Link 15: https://www.tiktok.com/tag/cachorro
# 2025-07-16 23:30:50,644 - INFO -    🎯 Số TikTok links tìm thấy: 14
# 2025-07-16 23:30:50,768 - INFO -    📜 Scroll 1: Tìm thấy 438 links
# 2025-07-16 23:30:50,942 - INFO -       ✅ Tìm thấy video ID: 7496578131843714309
# 2025-07-16 23:30:51,115 - INFO -       ✅ Tìm thấy video ID: 7523661420639030559
# 2025-07-16 23:30:51,289 - INFO -       ✅ Tìm thấy video ID: 7493547684062678290
# 2025-07-16 23:30:51,359 - INFO -       ✅ Tìm thấy video ID: 7469012501993393413
# 2025-07-16 23:30:51,516 - INFO -       ✅ Tìm thấy video ID: 7519121499287031070
# 2025-07-16 23:30:51,517 - INFO -    📊 Đã crawl được 5 video IDs cho #viral
# 2025-07-16 23:30:54,528 - INFO -    🔚 Đóng trình duyệt...
# 2025-07-16 23:30:57,138 - INFO - 🎉 Thành công! Đã crawl được 5 video IDs
# 2025-07-16 23:30:57,151 - INFO - IDs: ['7523661420639030559', '7493547684062678290', '7469012501993393413', '7496578131843714309', '7519121499287031070']
# 2025-07-16 23:31:03,787 - INFO - ✅ Kafka producer completed successfully
# 2025-07-16 23:31:03,790 - INFO - 2025-07-16 23:31:00,499 - __main__ - INFO - [run_kafka_producer_2.py:159] - 🔍 Starting run_kafka_producer.py...
# 2025-07-16 23:31:00,500 - __main__ - INFO - [run_kafka_producer_2.py:160] - 📋 Command line arguments: ['run_kafka_producer_2.py', '--ids_file', 'tiktok_ids.txt', '--topic', 'Test_with_MongoDB11']
# 2025-07-16 23:31:00,508 - __main__ - INFO - [run_kafka_producer_2.py:73] - ======================================================================
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:74] - 🚀 RUN_KAFKA_PRODUCER STARTING
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:75] - ======================================================================
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:76] - ⏰ Start time: 2025-07-16 23:31:00.509577
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:88] - ⚙️ Configuration:
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:89] -    Kafka Broker: localhost:9092
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:90] -    Topic: Test_with_MongoDB11
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:92] -    IDs file: tiktok_ids.txt
# 2025-07-16 23:31:00,509 - __main__ - INFO - [run_kafka_producer_2.py:95] -    Videos: 3
# ...
# 2025-07-16 23:40:57,011 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119971.000000, metadata 299945.001953, idle connection 537080.000000, request 30000.000000
# 2025-07-16 23:40:57,014 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 3
# 2025-07-16 23:40:57,014 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ProduceResponse_v7
# 2025-07-16 23:40:57,015 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 3 (3.521442413330078 ms): ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=46, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,015 - kafka.producer.sender - DEBUG - [sender.py:399] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Parsing produce response: ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=46, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,016 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:131] - Successfully produced messages to TopicPartition(topic='Test_with_MongoDB11', partition=0) with base offset 46
# 2025-07-16 23:40:57,016 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299940.470703, idle connection 537076.000000, request inf
# 2025-07-16 23:40:57,028 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7524247246729121055', 'url': 'https://www.tiktok.com/@funnypanda.media/video/7524247246729121055', 'username': 'funnypanda.media', 'author_name': 'Gấu mập hề hước', 'description': '#funnyvideos #funny #funnyanimals #comedyvideo #comdy #lucu #fy #fypシ #foryou #xuhuong ', 'hashtags': ['funnyvideos', 'funny', 'funnyanimals', 'comedyvideo', 'comdy', 'lucu', 'fy', 'fypシ', 'foryou', 'xuhuong'], 'playcount': 3400000, 'diggcount': 178300, 'commentcount': 3296, 'sharecount': 30400, 'music_title': 'son original', 'music_author': 'hakimducongo01🇨🇩', 'duration': 66, 'width': 576, 'height': 1024, 'created_time': '2025-07-07T15:02:48'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:40:57,029 - kafka.producer.kafka - DEBUG - [kafka.py:876] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Waking up the sender since TopicPartition(topic='Test_with_MongoDB11', partition=0) is either full or getting a new batch
# 2025-07-16 23:40:57,029 - kafka_producer_2 - INFO - [kafka_producer_2.py:484] - ✅ Đã gửi metadata cho video 7524247246729121055
# 2025-07-16 23:40:57,029 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9.000000, metadata 299927.208008, idle connection 537062.000000, request inf
# 2025-07-16 23:40:57,040 - kafka.producer.sender - DEBUG - [sender.py:257] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Nodes with data ready to send: {0}
# 2025-07-16 23:40:57,040 - kafka.producer.sender - DEBUG - [sender.py:258] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Created 1 produce requests: {0: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xd4\x00\x00\x00\x00\x02\xa0\xcd\x01\n\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xc5\x00\x00\x01\x98\x14\x1cQ\xc5\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xc2\n\x00\x00\x00\x08null\xac\n{"video_id": "7524247246729...')])])}
# 2025-07-16 23:40:57,041 - kafka.producer.sender - DEBUG - [sender.py:269] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Sending Produce Request: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xd4\x00\x00\x00\x00\x02\xa0\xcd\x01\n\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xc5\x00\x00\x01\x98\x14\x1cQ\xc5\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xc2\n\x00\x00\x00\x08null\xac\n{"video_id": "7524247246729...')])])
# 2025-07-16 23:40:57,041 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xd4\x00\x00\x00\x00\x02\xa0\xcd\x01\n\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xc5\x00\x00\x01\x98\x14\x1cQ\xc5\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xc2\n\x00\x00\x00\x08null\xac\n{"video_id": "7524247246729...')])])
# 2025-07-16 23:40:57,041 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Request 4 (timeout_ms 30000): ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xd4\x00\x00\x00\x00\x02\xa0\xcd\x01\n\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xc5\x00\x00\x01\x98\x14\x1cQ\xc5\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xc2\n\x00\x00\x00\x08null\xac\n{"video_id": "7524247246729...')])])
# 2025-07-16 23:40:57,041 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 0.000000, metadata 299914.656738, idle connection 537050.000000, request 30000.000000
# 2025-07-16 23:40:57,043 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119985.000000, metadata 299913.148926, idle connection 537048.000000, request 29998.492241
# 2025-07-16 23:40:57,046 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 4
# 2025-07-16 23:40:57,046 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ProduceResponse_v7
# 2025-07-16 23:40:57,047 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 4 (5.764245986938477 ms): ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=48, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,047 - kafka.producer.sender - DEBUG - [sender.py:399] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Parsing produce response: ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=48, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,048 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:131] - Successfully produced messages to TopicPartition(topic='Test_with_MongoDB11', partition=0) with base offset 48
# 2025-07-16 23:40:57,048 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299907.894043, idle connection 537043.000000, request inf
# 2025-07-16 23:40:57,054 - kafka.producer.kafka - DEBUG - [kafka.py:867] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Sending (key=None value={'video_id': '7524267390146759942', 'url': 'https://www.tiktok.com/@aserewa..comedy/video/7524267390146759942', 'username': 'aserewa..comedy', 'author_name': 'aserewa..comedy', 'description': '#voiceeffects #comment #viral_video #viralvideos #commedy #Ghan #voiceover #video ', 'hashtags': ['voiceeffects', 'comment', 'viral_video', 'viralvideos', 'commedy', 'ghan', 'voiceover', 'video'], 'playcount': 2200000, 'diggcount': 171400, 'commentcount': 5226, 'sharecount': 10400, 'music_title': 'original sound', 'music_author': 'aserewa..comedy', 'duration': 60, 'width': 576, 'height': 1024, 'created_time': '2025-07-07T16:20:28'} headers=[]) to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:40:57,054 - kafka.producer.kafka - DEBUG - [kafka.py:876] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Waking up the sender since TopicPartition(topic='Test_with_MongoDB11', partition=0) is either full or getting a new batch
# 2025-07-16 23:40:57,054 - kafka_producer_2 - INFO - [kafka_producer_2.py:484] - ✅ Đã gửi metadata cho video 7524267390146759942
# 2025-07-16 23:40:57,055 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 8.000000, metadata 299901.334473, idle connection 537036.000000, request inf
# 2025-07-16 23:40:57,055 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:40:57,056 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:583] - Waiting on produce to TopicPartition(topic='Test_with_MongoDB11', partition=0)
# 2025-07-16 23:40:57,057 - kafka.producer.sender - DEBUG - [sender.py:257] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Nodes with data ready to send: {0}
# 2025-07-16 23:40:57,057 - kafka.producer.sender - DEBUG - [sender.py:258] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Created 1 produce requests: {0: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xb2\x00\x00\x00\x00\x02\x86o\xcfz\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xde\x00\x00\x01\x98\x14\x1cQ\xde\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xfe\t\x00\x00\x00\x08null\xe8\t{"video_id": "7524267390146...')])])}
# 2025-07-16 23:40:57,058 - kafka.producer.sender - DEBUG - [sender.py:269] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Sending Produce Request: ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xb2\x00\x00\x00\x00\x02\x86o\xcfz\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xde\x00\x00\x01\x98\x14\x1cQ\xde\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xfe\t\x00\x00\x00\x08null\xe8\t{"video_id": "7524267390146...')])])
# 2025-07-16 23:40:57,058 - kafka.protocol.parser - DEBUG - [parser.py:58] - Sending request ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xb2\x00\x00\x00\x00\x02\x86o\xcfz\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xde\x00\x00\x01\x98\x14\x1cQ\xde\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xfe\t\x00\x00\x00\x08null\xe8\t{"video_id": "7524267390146...')])])
# 2025-07-16 23:40:57,058 - kafka.conn - DEBUG - [conn.py:1017] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Request 5 (timeout_ms 30000): ProduceRequest_v7(transactional_id=None, required_acks=-1, timeout=30000, topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, records=b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\xb2\x00\x00\x00\x00\x02\x86o\xcfz\x00\x00\x00\x00\x00\x00\x00\x00\x01\x98\x14\x1cQ\xde\x00\x00\x01\x98\x14\x1cQ\xde\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x01\xfe\t\x00\x00\x00\x08null\xe8\t{"video_id": "7524267390146...')])])
# 2025-07-16 23:40:57,060 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 0.000000, metadata 299896.488037, idle connection 537032.000000, request 30000.000000
# 2025-07-16 23:40:57,060 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 119994.000000, metadata 299896.488037, idle connection 537032.000000, request 30000.000000
# 2025-07-16 23:40:57,062 - kafka.protocol.parser - DEBUG - [parser.py:142] - Received correlation id: 5
# 2025-07-16 23:40:57,062 - kafka.protocol.parser - DEBUG - [parser.py:160] - Processing response ProduceResponse_v7
# 2025-07-16 23:40:57,062 - kafka.conn - DEBUG - [conn.py:1140] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Response 5 (2.4013519287109375 ms): ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=49, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,063 - kafka.producer.sender - DEBUG - [sender.py:399] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Parsing produce response: ProduceResponse_v7(topics=[(topic='Test_with_MongoDB11', partitions=[(partition=0, error_code=0, offset=49, timestamp=-1, log_start_offset=0)])], throttle_time_ms=0)
# 2025-07-16 23:40:57,063 - kafka.producer.record_accumulator - DEBUG - [record_accumulator.py:131] - Successfully produced messages to TopicPartition(topic='Test_with_MongoDB11', partition=0) with base offset 49
# 2025-07-16 23:40:57,063 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299893.088867, idle connection 537028.000000, request inf
# 2025-07-16 23:40:57,063 - kafka_producer_2 - INFO - [kafka_producer_2.py:489] - 🎉 Đã gửi xong metadata cho 5 video IDs trong tiktok_ids.txt!
# 2025-07-16 23:40:57,064 - __main__ - INFO - [run_kafka_producer_2.py:128] - ✅ Sending completed in 2.96s
# 2025-07-16 23:40:57,064 - __main__ - INFO - [run_kafka_producer_2.py:131] - 🧹 Cleaning up producer...
# 2025-07-16 23:40:57,064 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:40:57,065 - kafka.producer.kafka - INFO - [kafka.py:629] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Closing the Kafka producer with 4294967.0 secs timeout.
# 2025-07-16 23:40:57,065 - kafka.client - DEBUG - [client_async.py:677] - Timeouts: user 9999999990.000000, metadata 299890.783936, idle connection 537026.000000, request inf
# 2025-07-16 23:40:57,065 - kafka.producer.kafka - DEBUG - [kafka.py:916] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: Flushing accumulated records in producer.
# 2025-07-16 23:40:57,066 - kafka.producer.sender - DEBUG - [sender.py:114] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Beginning shutdown of Kafka producer I/O thread, sending remaining records.
# 2025-07-16 23:40:57,066 - kafka.conn - INFO - [conn.py:945] - <BrokerConnection client_id=kafka-python-producer-1, node_id=0 host=host.docker.internal:9092 <connected> [IPv4 ('192.168.1.97', 9092)]>: Closing connection.
# 2025-07-16 23:40:57,067 - kafka.producer.sender - DEBUG - [sender.py:138] - <Sender client_id=kafka-python-producer-1 transactional_id=None>: Shutdown of Kafka producer I/O thread has completed.
# 2025-07-16 23:40:57,067 - kafka.producer.kafka - DEBUG - [kafka.py:662] - <KafkaProducer client_id=kafka-python-producer-1 transactional_id=None>: The Kafka producer has closed.
# 2025-07-16 23:40:57,067 - __main__ - INFO - [run_kafka_producer_2.py:138] - ✅ Cleanup completed in 0.00s
# 2025-07-16 23:40:57,068 - __main__ - INFO - [run_kafka_producer_2.py:141] - 🎉 SUCCESS - All operations completed successfully!
# 2025-07-16 23:40:57,068 - __main__ - INFO - [run_kafka_producer_2.py:179] - ⏱️ Total execution time: 2.99s
# 2025-07-16 23:40:57,068 - __main__ - INFO - [run_kafka_producer_2.py:182] - 🎉 Program completed successfully!
#
# 2025-07-16 23:40:57,213 - INFO - ⏳ Sleeping 300s before next round...
